# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import lag_plot
from pandas.plotting import scatter_matrix
np.random.seed(3)

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3
# Out:
#              B          C
# 0     1.788628   0.436510
# 1     1.885126  -1.426983
# 2     1.607738  -1.781742
# 3     1.524996  -2.408743
# 4     1.481178  -2.885961
# ..         ...        ...
# 995 -79.526863  24.108796
# 996 -78.781642  22.710787
# 997 -78.703063  21.061850
# 998 -78.875319  20.245674
# 999 -79.878564  20.460504
#
# [1000 rows x 2 columns]

# %%
df3["A"] = pd.Series(list(range(len(df3))))
df3
# Out:
#              B          C    A
# 0     1.788628   0.436510    0
# 1     1.885126  -1.426983    1
# 2     1.607738  -1.781742    2
# 3     1.524996  -2.408743    3
# 4     1.481178  -2.885961    4
# ..         ...        ...  ...
# 995 -79.526863  24.108796  995
# 996 -78.781642  22.710787  996
# 997 -78.703063  21.061850  997
# 998 -78.875319  20.245674  998
# 999 -79.878564  20.460504  999
#
# [1000 rows x 3 columns]

# %%
df3.plot(x="A", y="B")

# %%
plt.figure()

# %%
df3.iloc[5]
# Out:
# B    0.167313
# C   -2.001338
# A    5.000000
# Name: 5, dtype: float64

# %%
 df3.iloc[5].plot.bar()

# %%
df3.loc[1:4,:]
# Out:
#           B         C  A
# 1  1.885126 -1.426983  1
# 2  1.607738 -1.781742  2
# 3  1.524996 -2.408743  3
# 4  1.481178 -2.885961  4

# %%
df3.loc[1:4,:].plot.bar()

# %%
df3.loc[1:4,:].plot.hist(alpha=0.5)

# %%
df3.loc[1:4,:].plot.box()

# %%
#all value must positive
df3.loc[6:9,:].plot.area()
print(df3.loc[6:9,:])
# Out:
#           B         C  A
# 6  1.048631 -0.291765  6
# 7  1.098665 -0.696443  7
# 8  0.553305 -2.242920  8
# 9  1.535673 -3.343987  9

# %%
df3.loc[6:9,:].plot.area(stacked=False)

# %%
 df3.plot.scatter(x="A", y="B")

# %%
df3.plot.hexbin(x="A", y="B", gridsize=25)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
df
# Out:
#             a         b         c         d
# 0    0.762425  0.092690  0.286937  0.701076
# 1    1.199222  0.999799  0.384916  1.979400
# 2   -0.527271  0.782043 -1.163006  2.374654
# 3   -0.266942  0.138239  1.362574 -0.211957
# 4   -0.864328 -1.875554 -0.294008  2.023187
# ..        ...       ...       ...       ...
# 995 -0.010853  0.654377 -1.067634  0.771399
# 996  0.135338  0.477236 -1.533673  2.384831
# 997 -0.498297 -1.906318  0.860792  0.167128
# 998 -0.784894 -1.244695  1.426661  0.385441
# 999 -0.656998 -1.552961  0.239156  2.091828
#
# [1000 rows x 4 columns]

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012807070>,
# ...
#       dtype=object)

# %%
ser = pd.Series(np.random.randn(1000))
ser
# Out:
# 0     -0.284162
# 1     -0.011127
# 2     -1.028756
# 3     -0.035311
# 4     -1.112942
#          ...
# 995   -0.820090
# 996   -1.855544
# 997   -1.102629
# 998   -0.517580
# 999    0.989962
# Length: 1000, dtype: float64

# %%
ser.plot.kde()

# %%
spacing = np.linspace(-99 * np.pi, 99 * np.pi, num=1000)
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(spacing))
data
# Out:
# 0      0.007376
# 1     -0.446980
# 2     -0.762493
# 3     -0.793936
# 4     -0.489244
#          ...
# 995    0.599780
# 996    0.907390
# 997    0.912560
# 998    0.598043
# 999    0.063701
# Length: 1000, dtype: float64

# %%
lag_plot(data)
